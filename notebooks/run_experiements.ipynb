# %%
from IPython.display import clear_output

# !nvidia-smi
# Out:
# Thu Aug 13 00:44:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/Victorgonl/AND-GloRe-WiP

# %cd AND-GloRe-WiP
# %ls .
# Out:
# Cloning into 'AND-GloRe-WiP'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 85 (delta 21), reused 79 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 35.85 KiB | 1019.00 KiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/AND-GloRe-WiP
# configs/  LICENSE  outputs/   requirements.txt  scripts/  src/
# data/     logs/    README.md  results/          setup.py

# %%
# !git fetch --all
# !git reset --hard origin/main
# !git clean -fd
# Out:
# Fetching origin
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 351 bytes | 175.00 KiB/s, done.
# From https://github.com/Victorgonl/AND-GloRe-WiP
#    aeb884b..c911dcd  main       -> origin/main
# HEAD is now at c911dcd Remove not used args in yaml

# %%
# %pip install -r requirements.txt
# %pip install -e .

clear_output()
# !cat requirements.txt
# Out:
# # Python 3.11
# hdbscan==0.8.44
# networkx==3.6.1
# numpy==2.4.3
# pandas==3.0.1
# scikit-learn==1.9.0
# torch
# torchdata==0.11.0
# tqdm==4.68.4
# PyYAML==6.0.3

# %%
# !mkdir data/whoiswhov1
# !wget -q -O data/whoiswhov1/preprocessed.csv https://github.com/Victorgonl/AND-GloRe-WiP/releases/download/whoiswhov1/preprocessed.csv
# !wget -q -O data/whoiswhov1/features.pt https://github.com/Victorgonl/AND-GloRe-WiP/releases/download/whoiswhov1/features.pt
clear_output()
# %ls data/whoiswhov1/

# %%
# !mkdir data/lagosandv1
# !wget -O data/lagosandv1/preprocessed.csv https://github.com/Victorgonl/AND-GloRe-WiP/releases/download/lagosandv1/preprocessed.csv
# !wget -O data/lagosandv1/features.pt https://github.com/Victorgonl/AND-GloRe-WiP/releases/download/lagosandv1/features.pt
clear_output()
# %ls data/lagosandv1/
# Out:
# features.pt  preprocessed.csv

# %%
# !python scripts/generate_networks.py --config configs/whoiswhov1.yaml
# Out:
# Traceback (most recent call last):
#   File "/content/AND-GloRe-WiP/scripts/generate_networks.py", line 3, in <module>
#     from andglore.networks import build_ambiguous_networks
#   File "/usr/local/lib/python3.12/dist-packages/andglore/networks/__init__.py", line 1, in <module>
#     from .build_networks import (
#   File "/usr/local/lib/python3.12/dist-packages/andglore/networks/build_networks.py", line 9, in <module>
#     import torch
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 442, in <module>
#     from torch._C import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 463, in _lock_unlock_module
# KeyboardInterrupt
# ^C

# %%
# !python scripts/run_experiment.py --config configs/whoiswhov1.yaml
# Out:
# [2026-08-12 20:14:03] Starting Experiment
#
# Experiments Args:seeds: (2026,)
# epochs: 50
# lr: 0.0001
# l2_coef: 0.0001
# feat_mask: 0.1
# adj_mask: 0.2
# hidden_dim: 128
# embed_dim: 64
# gnn_hidden_dim: 256
# proj_dim: 64
# temperature: 0.1
# dropout: 0.1
# gnn_dropout: 0.1
# gnn_alpha: 0.2
# min_distance_threshold: 0.1
# max_distance_threshold: 0.3
# step: 0.05
# device: cuda
#
# Running on all groups for dataset 'whoiswhov1'
#
# Running 1 iterations with seeds: (2026,)
#
# [2026-08-12 20:14:06] Run 0/1 - Name 0/50: aiqin_wang
# [2026-08-12 20:14:15] Results for name: aiqin_wang
# Runtime: 0:00:02
# pP: 90.73% pR: 100.00% pF1: 95.14%
# bP: 92.90% bR: 100.00% bF1: 96.32%
# ARI: 90.35%
#
# [2026-08-12 20:14:15] Run 0/1 - Name 1/50: baohong_zhang
# [2026-08-12 20:14:17] Results for name: baohong_zhang
# Runtime: 0:00:01
# pP: 100.00% pR: 66.79% pF1: 80.09%
# bP: 100.00% bR: 73.79% bF1: 84.92%
# ARI: 71.13%
#
# [2026-08-12 20:14:17] Run 0/1 - Name 2/50: barry_smith
# ...

# %%
# !python scripts/generate_networks.py --config configs/lagosandv1.yaml --max_orgs_per_author 3 --max_author_paper_ratio 0.01

# %%
# !python scripts/run_experiment.py --config configs/lagosandv1.yaml
# Out:
# [2026-08-13 01:22:25] Starting Experiment
#
# Experiments Args:seeds: (2026,)
# epochs: 15
# lr: 0.0001
# l2_coef: 0.0001
# feat_mask: 0.1
# adj_mask: 0.2
# hidden_dim: 128
# embed_dim: 64
# gnn_hidden_dim: 256
# proj_dim: 64
# temperature: 0.1
# dropout: 0.1
# gnn_dropout: 0.1
# gnn_alpha: 0.2
# min_distance_threshold: 0.1
# max_distance_threshold: 0.3
# step: 0.05
# device: cuda
#
# Running on all groups for dataset 'lagosandv1'
#
# Running 1 iterations with seeds: (2026,)
#
# [2026-08-13 01:22:30] Run 0/1 - Name 0/2440: aaron_marshall - Avg. F1: 0.0000
# [2026-08-13 01:22:32] Results for name: aaron_marshall
# Runtime: 0:00:00
# pP: 75.86% pR: 32.84% pF1: 45.83%
# bP: 88.89% bR: 43.92% bF1: 58.79%
# ARI: 31.07%
#
# [2026-08-13 01:22:32] Run 0/1 - Name 1/2440: aaron_saunders - Avg. F1: 0.2292
# [2026-08-13 01:22:32] Results for name: aaron_saunders
# Runtime: 0:00:00
# pP: 91.59% pR: 95.83% pF1: 93.67%
# bP: 93.45% bR: 93.79% bF1: 93.62%
# ARI: 86.11%
#
# ...
